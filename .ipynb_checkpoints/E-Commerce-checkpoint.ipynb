# %%
# %reload_ext sql

# %%
# %sql mysql+mysqlconnector://root:1234@localhost/sk

# %%
# %%sql
# use ecommerce;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE products (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     name VARCHAR(100),
#     category VARCHAR(50),
#     price INT,
#     brand VARCHAR(50),
#     rating DECIMAL(2,1)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO products (name, category, price, brand, rating) VALUES
# ('Blue Shirt', 'Clothing', 750, 'Denim', 3.8),
# ('Blue Jeans', 'Clothing', 800, 'Puma', 3.6),
# ('Black Jeans', 'Clothing', 750, 'Denim', 4.5),
# ('Blue Shirt', 'Clothing', 1000, 'Puma', 4.3),
# ('Chocolate Cake', 'Food', 25, 'Britannia', 3.7),
# ('Strawberry Cake', 'Food', 60, 'Cadbury', 4.1),
# ('Chocolate Cake', 'Food', 60, 'Cadbury', 2.5),
# ('Strawberry Cake', 'Food', 10, 'Britannia', 4.6),
# ('Smart Watch', 'Gadgets', 17000, 'Apple', 4.9),
# ('Smart Cam', 'Gadgets', 2600, 'Realme', 4.7),
# ('Smart TV', 'Gadgets', 40000, 'Sony', 4.0),
# ('Bourbon Small', 'Food', 10, 'Britannia', 3.9),
# ('Bourbon Special', 'Food', 15, 'Britannia', 4.6),
# ('Bourbon With Extra Cookies', 'Food', 30, 'Britannia', 4.4),
# ('White Shirt', 'Clothing', 700, 'Denim', 4.3),
# ('Black Shirt', 'Clothing', 600, 'Puma', 4.8),
# ('Black T-Shirt', 'Clothing', 600, 'Roadster', 4.2),
# ('White T-Shirt', 'Clothing', 700, 'Levis', 4.0),
# ('Blue T-Shirt', 'Clothing', 600, 'Nike', 4.7),
# ('Realme Smart Band', 'Gadgets', 3000, 'Realme', 4.6),
# ('Rare Cashews', 'Food', 1700, 'Aiwa', 3.9),
# ('Cashew Nuts', 'Food', 550, 'Upcrop', 4.3),
# ('Chocolate Cashew', 'Food', 670, 'Urban Platter', 3.5),
# ('Potato Chips India''s Magic Masala', 'Food', 42, 'Lay''s', 4.4),
# ('Banana Chips', 'Food', 550, 'Calicut Kerala', 4.3),
# ('Potato Chips Cream & Onion', 'Food', 63, 'Lay''s', 4.5),
# ('Potato Chips Classic Salted', 'Food', 45, 'Lay''s', 4.0),
# ('Harry Potter and the Philosopher''s Stone', 'Novel', 222, 'Bloomsbury', 4.7);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# []

# %%
# %%sql
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
# ...

# %%
# %%sql
# Select name,price from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [('Blue Shirt', 750),
#  ('Blue Jeans', 800),
#  ('Black Jeans', 750),
#  ('Blue Shirt', 1000),
#  ('Chocolate Cake', 25),
#  ('Strawberry Cake', 60),
#  ('Chocolate Cake', 60),
#  ('Strawberry Cake', 10),
#  ('Smart Watch', 17000),
#  ('Smart Cam', 2600),
#  ('Smart TV', 40000),
#  ('Bourbon Small', 10),
#  ('Bourbon Special', 15),
#  ('Bourbon With Extra Cookies', 30),
#  ('White Shirt', 700),
#  ('Black Shirt', 600),
#  ('Black T-Shirt', 600),
#  ('White T-Shirt', 700),
#  ('Blue T-Shirt', 600),
#  ('Realme Smart Band', 3000),
#  ('Rare Cashews', 1700),
#  ('Cashew Nuts', 550),
#  ('Chocolate Cashew', 670),
#  ("Potato Chips India's Magic Masala", 42),
#  ('Banana Chips', 550),
#  ('Potato Chips Cream & Onion', 63),
#  ('Potato Chips Classic Salted', 45),
#  ("Harry Potter and the Philosopher's Stone", 222)]

# %%
# %%sql
# Select * from products where price > 1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9'))]

# %%
# %%sql
# Select * from products where category = 'Clothing';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 9 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where rating > 4.5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 8 rows affected.
# [(8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (28, "Harry Potter and the Philosopher's Stone", 'Novel', 222, 'Bloomsbury', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where brand = 'Puma';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8'))]

# %%
# %%sql
# Select * from products Order by price;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [(8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
#  (27, 'Potato Chips Classic Salted', 'Food', 45, "Lay's", Decimal('4.0')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (26, 'Potato Chips Cream & Onion', 'Food', 63, "Lay's", Decimal('4.5')),
#  (28, "Harry Potter and the Philosopher's Stone", 'Novel', 222, 'Bloomsbury', Decimal('4.7')),
#  (22, 'Cashew Nuts', 'Food', 550, 'Upcrop', Decimal('4.3')),
# ...

# %%
# %%sql
# Select * from products Order by price Desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [(11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (23, 'Chocolate Cashew', 'Food', 670, 'Urban Platter', Decimal('3.5')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
# ...

# %%
# %%sql
# Select * from products Order by rating Desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [(9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (28, "Harry Potter and the Philosopher's Stone", 'Novel', 222, 'Bloomsbury', Decimal('4.7')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (26, 'Potato Chips Cream & Onion', 'Food', 63, "Lay's", Decimal('4.5')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
# ...

# %%
# %%sql
# Select * from products Order by price Desc Limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9'))]

# %%
# %%sql
# Select * from products where brand = 'Puma' Order by price;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3'))]

# %%
# %%sql
# SELECT name, price, brand from products where name in ('Blue Shirt','Black Jeans') Order by price Desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [('Blue Shirt', 1000, 'Puma'),
#  ('Blue Shirt', 750, 'Denim'),
#  ('Black Jeans', 750, 'Denim')]

# %%
# %%sql
# Select Distinct category from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Clothing',), ('Food',), ('Gadgets',), ('Novel',)]

# %%
# %%sql
# Select Distinct brand from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 16 rows affected.
# [('Denim',),
#  ('Puma',),
#  ('Britannia',),
#  ('Cadbury',),
#  ('Apple',),
#  ('Realme',),
#  ('Sony',),
#  ('Roadster',),
#  ('Levis',),
#  ('Nike',),
#  ('Aiwa',),
#  ('Upcrop',),
#  ('Urban Platter',),
#  ("Lay's",),
#  ('Calicut Kerala',),
#  ('Bloomsbury',)]

# %%
# %%sql
# Select Count(*) from products as Total_Products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(28,)]

# %%
# %%sql
# Select Max(price) as Highest_Price from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(40000,)]

# %%
# %%sql
# Select Min(price) as Lowest_Price from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(10,)]

# %%
# %%sql
# Select Avg(price) as Average_Price from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(Decimal('2612.5714'),)]

# %%
# %%sql
# Select Sum(price) as Total_Price from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(Decimal('73152'),)]

# %%
# %%sql
# SELECT category, COUNT(*) AS Total
# FROM products
# GROUP BY category;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Clothing', 9), ('Food', 14), ('Gadgets', 4), ('Novel', 1)]

# %%
# %%sql
# SELECT category,AVG(price) as Average_price from products GROUP BY category;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Clothing', Decimal('722.2222')),
#  ('Food', Decimal('273.5714')),
#  ('Gadgets', Decimal('15650.0000')),
#  ('Novel', Decimal('222.0000'))]

# %%
# %%sql
# SELECT brand,count(*) as Products from products GROUP BY brand;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 16 rows affected.
# [('Denim', 3),
#  ('Puma', 3),
#  ('Britannia', 5),
#  ('Cadbury', 2),
#  ('Apple', 1),
#  ('Realme', 2),
#  ('Sony', 1),
#  ('Roadster', 1),
#  ('Levis', 1),
#  ('Nike', 1),
#  ('Aiwa', 1),
#  ('Upcrop', 1),
#  ('Urban Platter', 1),
#  ("Lay's", 3),
#  ('Calicut Kerala', 1),
#  ('Bloomsbury', 1)]

# %%
# %%sql
# SELECT brand,AVG(rating) as Average_Rating from products GROUP By brand;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 16 rows affected.
# [('Denim', Decimal('4.20000')),
#  ('Puma', Decimal('4.23333')),
#  ('Britannia', Decimal('4.24000')),
#  ('Cadbury', Decimal('3.30000')),
#  ('Apple', Decimal('4.90000')),
#  ('Realme', Decimal('4.65000')),
#  ('Sony', Decimal('4.00000')),
#  ('Roadster', Decimal('4.20000')),
#  ('Levis', Decimal('4.00000')),
#  ('Nike', Decimal('4.70000')),
#  ('Aiwa', Decimal('3.90000')),
#  ('Upcrop', Decimal('4.30000')),
#  ('Urban Platter', Decimal('3.50000')),
#  ("Lay's", Decimal('4.30000')),
#  ('Calicut Kerala', Decimal('4.30000')),
#  ('Bloomsbury', Decimal('4.70000'))]

# %%
# %%sql
# Select category,COUNT(*) as Total from products Group by category HAVING COUNT(*) > 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [('Clothing', 9), ('Food', 14)]

# %%
# %%sql
# Select brand,AVG(rating) as Average_Rating from products Group by brand Having AVG(rating) > 4.5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Apple', Decimal('4.90000')),
#  ('Realme', Decimal('4.65000')),
#  ('Nike', Decimal('4.70000')),
#  ('Bloomsbury', Decimal('4.70000'))]

# %%
# %%sql
# SELECT * from products
# Where name Like 'B%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 11 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (25, 'Banana Chips', 'Food', 550, 'Calicut Kerala', Decimal('4.3'))]

# %%
# %%sql
# SELECT * from products Where name Like '%Shirt';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# SELECT * from products Where name Like '%Cake';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [(5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6'))]

# %%
# %%sql
# SELECT * from products Where name like 'Blue%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where price between 500 and 1000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 12 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (22, 'Cashew Nuts', 'Food', 550, 'Upcrop', Decimal('4.3')),
#  (23, 'Chocolate Cashew', 'Food', 670, 'Urban Platter', Decimal('3.5')),
#  (25, 'Banana Chips', 'Food', 550, 'Calicut Kerala', Decimal('4.3'))]

# %%
# %%sql
# Select * from products where brand in ('Puma','Nike','Sony');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# SELECT distinct brand from products Where brand like '_____';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Denim',), ('Apple',), ('Levis',), ("Lay's",)]

# %%
# %%sql
# SELECT * from products Where category = 'Food' and name not Like '%Cake';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 10 rows affected.
# [(12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9')),
#  (22, 'Cashew Nuts', 'Food', 550, 'Upcrop', Decimal('4.3')),
#  (23, 'Chocolate Cashew', 'Food', 670, 'Urban Platter', Decimal('3.5')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
#  (25, 'Banana Chips', 'Food', 550, 'Calicut Kerala', Decimal('4.3')),
#  (26, 'Potato Chips Cream & Onion', 'Food', 63, "Lay's", Decimal('4.5')),
#  (27, 'Potato Chips Classic Salted', 'Food', 45, "Lay's", Decimal('4.0'))]

# %%
# %%sql
# Select * from products where brand = 'Apple' and price < 20000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9'))]

# %%
# %%sql
# Select * from products where brand = 'Britannia' or rating > 4.0;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 20 rows affected.
# [(3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
# ...

# %%
# %%sql
# Select * from products where not category='Food';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 14 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
# ...

# %%
# %%sql
# Select * from products where brand = 'Realme' and rating > 4 or brand = 'Apple';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6'))]

# %%
# %%sql
# Select * from products where category = 'Clothing' and not name Like '%Jeans%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where brand in ('Puma','Denim') and not name Like '%Shirt%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [(2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5'))]

# %%
# %%sql
# Select * from products where price < 100 or category = 'Food';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 14 rows affected.
# [(5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9')),
#  (22, 'Cashew Nuts', 'Food', 550, 'Upcrop', Decimal('4.3')),
#  (23, 'Chocolate Cashew', 'Food', 670, 'Urban Platter', Decimal('3.5')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
#  (25, 'Banana Chips', 'Food', 550, 'Calicut Kerala', Decimal('4.3')),
#  (26, 'Potato Chips Cream & Onion', 'Food', 63, "Lay's", Decimal('4.5')),
# ...

# %%
# %%sql
# Select * from products where name not like '%Chocolate%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 25 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
# ...

# %%
# %%sql
# Select * from products where category = 'Clothing' and price < 700;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where brand = 'Denim' and rating > 4;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [(3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3'))]

# %%
# %%sql
# Select * from products where price <= 1000 and rating > 4;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 15 rows affected.
# [(3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (22, 'Cashew Nuts', 'Food', 550, 'Upcrop', Decimal('4.3')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
#  (25, 'Banana Chips', 'Food', 550, 'Calicut Kerala', Decimal('4.3')),
# ...

# %%
# %%sql
# Select * from products where rating > 3.6 and price < 1000 and brand = 'Puma';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8'))]

# %%
# %%sql
# Select * from products where brand in ('Puma','Denim','Nike');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where brand = 'Redmi' and rating > 4 or brand = 'OnePlus';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# Select * from products where name Like '%Cake%' and brand in ('Cadbury','Britannia') and rating > 4.0;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [(6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6'))]

# %%
# %%sql
# Select * from products where (brand = 'Puma' and rating > 3.5) or (brand = 'Denim' and rating > 4.0);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8'))]

# %%
# %%sql
# Select * from products where brand in ('Puma','Nike') and not name like '%black shirts%';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [(2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select * from products where brand in ('Puma','Levis','Mufti','lee','denim');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [(1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0'))]

# %%
# %%sql
# Select * from products where brand in ('Britannia','Cadbury',"Lay's") and category = 'Food';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 10 rows affected.
# [(5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (6, 'Strawberry Cake', 'Food', 60, 'Cadbury', Decimal('4.1')),
#  (7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (24, "Potato Chips India's Magic Masala", 'Food', 42, "Lay's", Decimal('4.4')),
#  (26, 'Potato Chips Cream & Onion', 'Food', 63, "Lay's", Decimal('4.5')),
#  (27, 'Potato Chips Classic Salted', 'Food', 45, "Lay's", Decimal('4.0'))]

# %%
# %%sql
# Select name,price,brand from products where price Between 2000 and 3000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [('Smart Cam', 2600, 'Realme'), ('Realme Smart Band', 3000, 'Realme')]

# %%
# %%sql
# Select * from products Order by price Desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 28 rows affected.
# [(11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (20, 'Realme Smart Band', 'Gadgets', 3000, 'Realme', Decimal('4.6')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (21, 'Rare Cashews', 'Food', 1700, 'Aiwa', Decimal('3.9')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (3, 'Black Jeans', 'Clothing', 750, 'Denim', Decimal('4.5')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (23, 'Chocolate Cashew', 'Food', 670, 'Urban Platter', Decimal('3.5')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
# ...

# %%
# %%sql
# Select * from products where name Like '%Shirt%' Order by price desc;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [(4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3')),
#  (1, 'Blue Shirt', 'Clothing', 750, 'Denim', Decimal('3.8')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (18, 'White T-Shirt', 'Clothing', 700, 'Levis', Decimal('4.0')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (17, 'Black T-Shirt', 'Clothing', 600, 'Roadster', Decimal('4.2')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7'))]

# %%
# %%sql
# Select distinct brand from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 16 rows affected.
# [('Denim',),
#  ('Puma',),
#  ('Britannia',),
#  ('Cadbury',),
#  ('Apple',),
#  ('Realme',),
#  ('Sony',),
#  ('Roadster',),
#  ('Levis',),
#  ('Nike',),
#  ('Aiwa',),
#  ('Upcrop',),
#  ('Urban Platter',),
#  ("Lay's",),
#  ('Calicut Kerala',),
#  ('Bloomsbury',)]

# %%
# %%sql
# Select distinct category from products;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Clothing',), ('Food',), ('Gadgets',), ('Novel',)]

# %%
# %%sql
# Select * from products order by rating desc Limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (19, 'Blue T-Shirt', 'Clothing', 600, 'Nike', Decimal('4.7')),
#  (28, "Harry Potter and the Philosopher's Stone", 'Novel', 222, 'Bloomsbury', Decimal('4.7'))]

# %%
# %%sql
# Select * from products order by price Limit 5;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (5, 'Chocolate Cake', 'Food', 25, 'Britannia', Decimal('3.7')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4'))]

# %%
# %%sql
# Select * from products where brand = 'Puma' order by rating desc Limit 2;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [(16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3'))]

# %%
# %%sql
# Select * from products where brand = 'Puma' order by price Limit 3;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8')),
#  (2, 'Blue Jeans', 'Clothing', 800, 'Puma', Decimal('3.6')),
#  (4, 'Blue Shirt', 'Clothing', 1000, 'Puma', Decimal('4.3'))]

# %%
# %%sql
# Select * from products Order by id Limit 10  offset 6;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 10 rows affected.
# [(7, 'Chocolate Cake', 'Food', 60, 'Cadbury', Decimal('2.5')),
#  (8, 'Strawberry Cake', 'Food', 10, 'Britannia', Decimal('4.6')),
#  (9, 'Smart Watch', 'Gadgets', 17000, 'Apple', Decimal('4.9')),
#  (10, 'Smart Cam', 'Gadgets', 2600, 'Realme', Decimal('4.7')),
#  (11, 'Smart TV', 'Gadgets', 40000, 'Sony', Decimal('4.0')),
#  (12, 'Bourbon Small', 'Food', 10, 'Britannia', Decimal('3.9')),
#  (13, 'Bourbon Special', 'Food', 15, 'Britannia', Decimal('4.6')),
#  (14, 'Bourbon With Extra Cookies', 'Food', 30, 'Britannia', Decimal('4.4')),
#  (15, 'White Shirt', 'Clothing', 700, 'Denim', Decimal('4.3')),
#  (16, 'Black Shirt', 'Clothing', 600, 'Puma', Decimal('4.8'))]
