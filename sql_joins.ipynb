# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:1234@localhost/sk

# %%
# %%sql
# CREATE DATABASE ElearningDB;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# []

# %%
# %%sql
# USE ElearningDB;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Instructor (
#     instructor_id INT PRIMARY KEY AUTO_INCREMENT,
#     instructor_name VARCHAR(100),
#     email VARCHAR(100),
#     experience INT
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Course (
#     course_id INT PRIMARY KEY AUTO_INCREMENT,
#     course_name VARCHAR(100),
#     price DECIMAL(10,2),
#     duration VARCHAR(50),
#     instructor_id INT,
#     FOREIGN KEY (instructor_id)
#     REFERENCES Instructor(instructor_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Student (
#     student_id INT PRIMARY KEY AUTO_INCREMENT,
#     student_name VARCHAR(100),
#     email VARCHAR(100),
#     phone VARCHAR(15)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Enrolls (
#     enroll_id INT PRIMARY KEY AUTO_INCREMENT,
#     student_id INT,
#     course_id INT,
#     enroll_date DATE,
#     FOREIGN KEY (student_id)
#     REFERENCES Student(student_id),
#     FOREIGN KEY (course_id)
#     REFERENCES Course(course_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE Reviews (
#     review_id INT PRIMARY KEY AUTO_INCREMENT,
#     course_id INT,
#     student_id INT,
#     rating INT,
#     review_text VARCHAR(255),
#     review_date DATE,
#     FOREIGN KEY (course_id)
#     REFERENCES Course(course_id),
#     FOREIGN KEY (student_id)
#     REFERENCES Student(student_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 0 rows affected.
# []

# %%
# %%sql
# SELECT
#     s.student_name,
#     c.course_name,
#     i.instructor_name,
#     e.enroll_date,
#     r.rating,
#     r.review_text
# FROM Student s
# JOIN Enrolls e
#     ON s.student_id = e.student_id
# JOIN Course c
#     ON e.course_id = c.course_id
# JOIN Instructor i
#     ON c.instructor_id = i.instructor_id
# LEFT JOIN Reviews r
#     ON s.student_id = r.student_id
#     AND c.course_id = r.course_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [('Saravana', 'Python', 'John', datetime.date(2026, 7, 1), 5, 'Excellent Course'),
#  ('Kumar', 'Python', 'John', datetime.date(2026, 7, 3), 4, 'Very Good'),
#  ('Saravana', 'SQL', 'John', datetime.date(2026, 7, 2), 5, 'Loved SQL'),
#  ('Dharshini', 'Tableau', 'John', datetime.date(2026, 7, 7), 5, 'Very useful Tableau course'),
#  ('Saravana', 'Power BI', 'John', datetime.date(2026, 7, 7), 5, 'Excellent Power BI Course')]

# %%
# %%sql
# SELECT * FROM Instructor;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [(1, 'John', 'john@gmail.com', 8)]

# %%
# %%sql
# SELECT * FROM Course;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [(1, 'Python', Decimal('2999.00'), '2 Months', 1),
#  (2, 'SQL', Decimal('1999.00'), '1 Month', 1),
#  (3, 'Tableau', Decimal('2999.00'), '2 Months', 1),
#  (4, 'Power BI', Decimal('2499.00'), '45 Days', 1)]

# %%
# %%sql
# SELECT * FROM Enrolls;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 6 rows affected.
# [(5, 1, 1, datetime.date(2026, 7, 1)),
#  (6, 1, 2, datetime.date(2026, 7, 2)),
#  (7, 2, 1, datetime.date(2026, 7, 3)),
#  (9, 1, 4, datetime.date(2026, 7, 7)),
#  (10, 4, 3, datetime.date(2026, 7, 7)),
#  (11, 3, 3, datetime.date(2026, 7, 7))]

# %%
# %%sql
# SELECT * FROM Reviews;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 6 rows affected.
# [(1, 1, 1, 5, 'Excellent Course', datetime.date(2026, 7, 10)),
#  (2, 1, 2, 4, 'Very Good', datetime.date(2026, 7, 11)),
#  (3, 2, 1, 5, 'Loved SQL', datetime.date(2026, 7, 12)),
#  (5, 4, 1, 5, 'Excellent Power BI Course', datetime.date(2026, 7, 8)),
#  (6, 3, 4, 5, 'Very useful Tableau course', datetime.date(2026, 7, 8)),
#  (7, 3, 3, 5, 'Excellent course', datetime.date(2026, 7, 8))]

# %%
# %%sql
# SELECT * from Student;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 5 rows affected.
# [(1, 'Saravana', 'saravana@gmail.com', '9876543210'),
#  (2, 'Kumar', 'kumar@gmail.com', '9876543211'),
#  (3, 'Priya', 'priya@gmail.com', '9876543212'),
#  (4, 'Dharshini', 'dharshini@gmail.com', '9876543215'),
#  (5, 'Rahul', 'rahul@gmail.com', '9876543216')]

# %%
# %%sql
# Select course_name, instructor_name from Course
# Natural Join Instructor where instructor_name = 'John';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 4 rows affected.
# [('Python', 'John'),
#  ('SQL', 'John'),
#  ('Tableau', 'John'),
#  ('Power BI', 'John')]

# %%
# %%sql
# Select instructor_name,email from Course
# Natural Join Instructor where course_name = 'Python';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [('John', 'john@gmail.com')]

# %%
# %%sql
# Select instructor_name,duration from Course
# Natural Join Instructor where course_name = 'Power BI';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [('John', '45 Days')]

# %%
# %%sql
# Select Student.student_name, Reviews.review_text, Reviews.review_date from Student
# Inner Join Reviews on Student.student_id = Reviews.student_id
# where Reviews.course_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [('Saravana', 'Excellent Course', datetime.date(2026, 7, 10)),
#  ('Kumar', 'Very Good', datetime.date(2026, 7, 11))]

# %%
# %%sql
# Select Student.student_name, Student.email, Student.phone from Student
# Inner Join Enrolls on Student.student_id = Enrolls.student_id
# where Enrolls.course_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [('Saravana', 'saravana@gmail.com', '9876543210'),
#  ('Kumar', 'kumar@gmail.com', '9876543211')]

# %%
# %%sql
# Select Reviews.course_id,Reviews.review_text,Reviews.review_date from Reviews
# Inner Join Student on Student.student_id = Reviews.student_id
# where Student.student_name = 'Saravana';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [(1, 'Excellent Course', datetime.date(2026, 7, 10)),
#  (2, 'Loved SQL', datetime.date(2026, 7, 12)),
#  (4, 'Excellent Power BI Course', datetime.date(2026, 7, 8))]

# %%
# %%sql
# Select Student.student_name from Student
# Left Join Enrolls on Student.student_id = Enrolls.student_id
# where Enrolls.course_id is null;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 1 rows affected.
# [('Rahul',)]

# %%
# %%sql
# Select Student.student_name , Enrolls.course_id from Student
# Left Join Enrolls on Student.student_id = Enrolls.student_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 7 rows affected.
# [('Saravana', 1),
#  ('Saravana', 2),
#  ('Saravana', 4),
#  ('Kumar', 1),
#  ('Priya', 3),
#  ('Dharshini', 3),
#  ('Rahul', None)]

# %%
# %%sql
# Select Course.course_name, Student.student_name from Course
# Inner Join Enrolls
# ON Course.course_id = Enrolls.course_id
# Inner Join Student
# ON Enrolls.student_id = Student.student_id
# where Course.instructor_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 6 rows affected.
# [('Python', 'Saravana'),
#  ('SQL', 'Saravana'),
#  ('Python', 'Kumar'),
#  ('Power BI', 'Saravana'),
#  ('Tableau', 'Dharshini'),
#  ('Tableau', 'Priya')]

# %%
# %%sql
# Select Student.student_name as Full_Name from Student
# Inner Join Reviews
# On Student.student_id = Reviews.student_id
# Inner Join Course
# On Reviews.course_id = Course.course_id
# where Course.course_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 2 rows affected.
# [('Saravana',), ('Kumar',)]

# %%
# %%sql
# Select Course.course_name from Course
# Inner Join Enrolls
# On Course.course_id = Enrolls.course_id
# Inner Join Student
# On Enrolls.student_id = Student.student_id
# where Student.student_name = 'Saravana';
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 3 rows affected.
# [('Python',), ('SQL',), ('Power BI',)]

# %%
# %%sql
# Select Course.course_name ,Student.student_name
# from Course Cross Join Student;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/sk
# 20 rows affected.
# [('Power BI', 'Saravana'),
#  ('Tableau', 'Saravana'),
#  ('SQL', 'Saravana'),
#  ('Python', 'Saravana'),
#  ('Power BI', 'Kumar'),
#  ('Tableau', 'Kumar'),
#  ('SQL', 'Kumar'),
#  ('Python', 'Kumar'),
#  ('Power BI', 'Priya'),
#  ('Tableau', 'Priya'),
#  ('SQL', 'Priya'),
#  ('Python', 'Priya'),
#  ('Power BI', 'Dharshini'),
#  ('Tableau', 'Dharshini'),
#  ('SQL', 'Dharshini'),
#  ('Python', 'Dharshini'),
#  ('Power BI', 'Rahul'),
#  ('Tableau', 'Rahul'),
#  ('SQL', 'Rahul'),
#  ('Python', 'Rahul')]
